# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading the dataset and and reading
df = pd.read_csv('housing_data.csv')
df.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
#checking the null value
df.isnull().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
#checking all the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
#calculating shape of the data
df.shape
# Out:
# (1460, 81)

# %%
# getting some information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Because we have already index column
df.drop(['Unnamed: 0'],axis=1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   int64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
#Dropping MasVnrType and Alley beacuse most of the data are missed
df.drop(['Alley' , 'MasVnrType'], axis = 1 , inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   int64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
df['Exterior1st'].unique()
# Out:
# array(['VinylSd', 'MetalSd', 'Wd Sdng', 'HdBoard', 'BrkFace', 'WdShing',
#        'CemntBd', 'Plywood', 'AsbShng', 'Stucco', 'BrkComm', 'AsphShn',
#        'Stone', 'ImStucc', 'CBlock'], dtype=object)

# %%
df['Exterior2nd'].unique()
# Out:
# array(['VinylSd', 'MetalSd', 'Wd Shng', 'HdBoard', 'Plywood', 'Wd Sdng',
#        'CmentBd', 'BrkFace', 'Stucco', 'AsbShng', 'Brk Cmn', 'ImStucc',
#        'AsphShn', 'Stone', 'Other', 'CBlock'], dtype=object)

# %%
# Dropping Exterior2nd because both are containing same information
df.drop(['Exterior2nd'], axis =1 ,  inplace = True)

# %%
#checking null values
df['GarageYrBlt'].isnull().sum()
# Out:
# 81

# %%
#filling null value with mean
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())

# %%
df['GarageYrBlt'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   int64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
#checkinh null value
df['Electrical'].isnull().sum()
# Out:
# 1

# %%
# filling null value with mode
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# %%
df['Electrical'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   int64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
# Identify the numerical and the categorical columns as:
numerical_columns = df.select_dtypes(include=['number']).columns.to_list()
categorical_columns = df.select_dtypes(include=['object']).columns.to_list()

# %%
categorical_columns
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MoSold',
#  'SaleType',
#  'SaleCondition']

# %%
numerical_columns
# Out:
# ['LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'YrSold',
#  'SalePrice']

# %%
sns.barplot(data = df , x= 'SaleCondition', y='SalePrice')
### conclusion For Partial Salecondition SalePrice is very high and for adjland saleprice is low
# Out:
# <Axes: xlabel='SaleCondition', ylabel='SalePrice'>

# %%
sns.countplot(data=df ,  x='SaleCondition')
## count of the normal is high and very low for the adjland
# Out:
# <Axes: xlabel='SaleCondition', ylabel='count'>

# %%
sns.countplot(data=df ,  x='SaleType')
## Customer love to buy with WD as compare to rest
# Out:
# <Axes: xlabel='SaleType', ylabel='count'>

# %%
sns.countplot(data=df ,  x='MoSold')
#Most of the sales is done in june july and may month
# Out:
# <Axes: xlabel='MoSold', ylabel='count'>

# %%
sns.countplot(data=df ,  x='MiscFeature')
#People not interested in MiscFeature
# Out:
# <Axes: xlabel='MiscFeature', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Fence')
#Fence is also not liked by people
# Out:
# <Axes: xlabel='Fence', ylabel='count'>

# %%
sns.countplot(data=df ,  x='PoolQC')
#almost 95% people not interested in PoolQC
# Out:
# <Axes: xlabel='PoolQC', ylabel='count'>

# %%
sns.countplot(data=df ,  x='GarageType')
# ATTACHED Garage is liked by Most of the people and very rarely people chhose 2Types Garage type
# Out:
# <Axes: xlabel='GarageType', ylabel='count'>

# %%
sns.countplot(data=df ,  x='GarageFinish')
# Most liked garagefinish is Unf
# Out:
# <Axes: xlabel='GarageFinish', ylabel='count'>

# %%
sns.countplot(data=df ,  x='GarageQual')
# 95% Customer like TA Quality of Garage
# Out:
# <Axes: xlabel='GarageQual', ylabel='count'>

# %%
sns.countplot(data=df ,  x='GarageCond')
# 95% Customer like TA conditionof Garage
# Out:
# <Axes: xlabel='GarageCond', ylabel='count'>

# %%
sns.countplot(data=df ,  x='PavedDrive')
# Customer like to buy PavedDrive
# Out:
# <Axes: xlabel='PavedDrive', ylabel='count'>

# %%
sns.countplot(data=df ,  x='CentralAir') 
# CentralAir is one of the key component of the customer , Most of the customer Like it
# Out:
# <Axes: xlabel='CentralAir', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Electrical')
# Electrical type's SBrkr count is very high it means Customer want their Electical should be SBrkr
# Out:
# <Axes: xlabel='Electrical', ylabel='count'>

# %%
sns.countplot(data=df ,  x='KitchenQual')
#First choice for KitchenQuality is TA and then GD and then EX and Fa
# Out:
# <Axes: xlabel='KitchenQual', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Functional')
# Fnctional Typ is most of the Customer' choice and rest is liked by 5-10% customer
# Out:
# <Axes: xlabel='Functional', ylabel='count'>

# %%
sns.countplot(data=df ,  x='FireplaceQu')
# Most of the customer dont want FireplaceQu
# Out:
# <Axes: xlabel='FireplaceQu', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Heating')
#Most of the Customer wants heating type GasA
# Out:
# <Axes: xlabel='Heating', ylabel='count'>

# %%
sns.countplot(data=df ,  x='HeatingQC')
# First choice of customer for heatingQC is EX then TA after that GD , FA and PO are rarely liked
# Out:
# <Axes: xlabel='HeatingQC', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Exterior1st')
plt.xticks(rotation = 'vert0ical')
plt.show()
# 500+ customers like Vinylsd Exterior1st and Metalsd, Wd sdng, HD board is liked by almost 200 customers rest are within 100

# %%
sns.countplot(data=df ,  x='ExterQual')
# ExterQual TA is most of the customers first choice after that Gd is second
# Out:
# <Axes: xlabel='ExterQual', ylabel='count'>

# %%
sns.countplot(data=df ,  x='ExterCond')
# ExterCond TA is most of the customers choice (85%)
# Out:
# <Axes: xlabel='ExterCond', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Foundation')
#Here we can observe that PConc and CBlock almost  most liked by customers
# Out:
# <Axes: xlabel='Foundation', ylabel='count'>

# %%
sns.countplot(data=df ,  x='BsmtQual')
#Here we can observe that GD and TA most liked by customers
# Out:
# <Axes: xlabel='BsmtQual', ylabel='count'>

# %%
sns.countplot(data=df ,  x='BsmtCond')
# BsmtCond TA is most of the customers choice
# Out:
# <Axes: xlabel='BsmtCond', ylabel='count'>

# %%
sns.countplot(data=df ,  x='BsmtExposure')
# Customer not interested in BsmtExposure
# Out:
# <Axes: xlabel='BsmtExposure', ylabel='count'>

# %%
sns.countplot(data=df ,  x='BsmtFinType1')
# UNF and GLQ Most in demands
# Out:
# <Axes: xlabel='BsmtFinType1', ylabel='count'>

# %%
sns.countplot(data=df ,  x='BsmtFinType2')
# Unf is first choice for BsmtFinType2
# Out:
# <Axes: xlabel='BsmtFinType2', ylabel='count'>

# %%
sns.countplot(data=df ,  x='MSSubClass')
plt.xticks(rotation = 'vertical')
plt.show()
# SC20 in more demanded by customer after SC60 ,rest is less in demand

# %%
sns.countplot(data=df ,  x='MSZoning')
# MSZoning RL is first choice by customers C(all) is very few people demand
# Out:
# <Axes: xlabel='MSZoning', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Street')
# it almost looks like one sided like 99% customers wants Pave street
# Out:
# <Axes: xlabel='Street', ylabel='count'>

# %%
sns.countplot(data=df ,  x='LotShape')
# Reg come at first place ,IR1 second AND IR2 at 3 and at the end IR3 by customers choice
# Out:
# <Axes: xlabel='LotShape', ylabel='count'>

# %%
sns.countplot(data=df ,  x='LandContour')
# Lvl is first choice by customers
# Out:
# <Axes: xlabel='LandContour', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Utilities')
# Almost 99 customers like AllPub it means AllPub is in demand
# Out:
# <Axes: xlabel='Utilities', ylabel='count'>

# %%
sns.countplot(data=df ,  x='LotConfig')
# we can see 100+ customer like inside LotConfig
# Out:
# <Axes: xlabel='LotConfig', ylabel='count'>

# %%
sns.countplot(data=df ,  x='LandSlope')
# LamdSlope Gtl is 1200+people choice
# Out:
# <Axes: xlabel='LandSlope', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Neighborhood')
plt.xticks(rotation = 'vertical')
plt.show()
# NAmes got high count after that collgcr (these 2 most liked by customers)

# %%
sns.countplot(data=df ,  x='Condition1')
# Customer want to buy houses which have norm cond
# Out:
# <Axes: xlabel='Condition1', ylabel='count'>

# %%
sns.countplot(data=df ,  x='Condition2')
# Customer want to buy houses which have norm cond
# Out:
# <Axes: xlabel='Condition2', ylabel='count'>

# %%
sns.countplot(data=df ,  x='BldgType')
#1Fam BldgType is most of the people choice
# Out:
# <Axes: xlabel='BldgType', ylabel='count'>

# %%
sns.countplot(data=df ,  x='HouseStyle')
# 1Story and 2Story came at 1st and 2nd choice for HouseStyle
# Out:
# <Axes: xlabel='HouseStyle', ylabel='count'>

# %%
sns.countplot(data=df ,  x='RoofMatl')
plt.xticks(rotation = 'vertical')
plt.show()
# RoofMatl CompShg preferred by the customers

# %%
sns.countplot(data=df ,  x='RoofStyle')
# Goble id preferred for the Roofstyle
# Out:
# <Axes: xlabel='RoofStyle', ylabel='count'>
